# %% [markdown]
# # 🐼 Mastering Pandas: 100 Problems
#
# Welcome to **Mastering Pandas: 100 Problems!** 🚀
#
# This repository contains **100 carefully crafted Pandas problems** to help you solidify your knowledge and become a **Pandas pro**. Whether you're a beginner or looking to refine your skills, these exercises will cover everything from basic operations to advanced data manipulation.
#
# ---
#
# ## 📜 Here are the 100 Pandas Problems
#
# Each problem is designed to test and enhance your understanding of **Pandas**, a powerful library for data analysis and manipulation in Python.
#
# ✅ **Covers topics such as:**
# - DataFrames & Series basics
# - Indexing & Selection
# - Data Cleaning
# - Grouping & Aggregations
# - Merging & Joining
# - Time Series Analysis
# - Performance Optimization
# - And much more...
#
# 📂 All problems are provided in a structured format, making it easy to follow along!
#
# 📁 **Datasets**: You can access the datasets required for these problems [here](https://drive.google.com/drive/folders/19eJeF0aC41ma7bSBEtsygRJOk_F2pObs?usp=drive_link).
#
# ---
#
# ## 🏆 Created By
# 👤 **Adarsha Rimal**
# 🔗 [LinkedIn](https://www.linkedin.com/in/adarsha-rimal-86007532b/) <img src="https://cdn-icons-png.flaticon.com/512/174/174857.png" width="16" height="16">
# ✍️ [Medium](https://medium.com/@cristianoadarsha) <img src="https://cdn-icons-png.flaticon.com/512/2111/2111503.png" width="16" height="16">
# 🐙 [GitHub](https://github.com/AdarshaRimal) <img src="https://cdn-icons-png.flaticon.com/512/2111/2111425.png" width="16" height="16">
# 📧 cristianoadarsha@gmail.com
#
# ---
#
# ## 🤝 Contribute, Share & Give Feedback!
# Your **feedback, contributions, and shares** will make this even better! 💡🚀
# - Found a mistake? **Submit a PR!**
# - Have an alternative solution? **Let's discuss!**
# - Share this with friends & colleagues 📢
#
# ⭐ **If you find this useful, don't forget to star this repository!** ⭐
#
# ---
#
# 📌 **Let’s Master Pandas Together!** 🐼🔥

# %% [markdown]
# # 100 Pandas Problems

# %% [markdown]
# ## Basic Pandas Questions

# %% [markdown]
# 1. How do you import Pandas in Python?

# %% [markdown]
# 2. How do you read a CSV file into a Pandas DataFrame?

# %% [markdown]
# 3. How do you display the first five rows of a DataFrame?

# %% [markdown]
# 4. How do you check the number of rows and columns in a DataFrame?

# %% [markdown]
# 5. How do you get the column names of a DataFrame?

# %% [markdown]
# 6. How do you check the data types of each column in a DataFrame?

# %% [markdown]
# 7. How do you convert a column’s data type to another type (e.g., string to integer)?

# %% [markdown]
# 8. How do you check for missing values in a DataFrame?

# %% [markdown]
# 9. How do you fill missing values with a specific value?

# %% [markdown]
# 10. How do you drop rows with missing values?

# %% [markdown]
# 11. How do you drop columns with missing values?

# %% [markdown]
# 12.How do you reset the index of a DataFrame?

# %% [markdown]
# 13. How do you set a specific column as the index?

# %% [markdown]
# 14. How do you sort a DataFrame based on a column?

# %% [markdown]
# 15. How do you select a single column from a DataFrame?

# %% [markdown]
# 16. How do you select multiple columns from a DataFrame?

# %% [markdown]
# 17. How do you filter rows based on a condition?

# %% [markdown]
# 18. How do you filter rows based on multiple conditions?

# %% [markdown]
# 19. How do you retrieve unique values from a column?

# %% [markdown]
# 20. How do you count the occurrences of each unique value in a column?

# %% [markdown]
# ## Intermediate Pandas Questions

# %% [markdown]
# 21. How do you rename columns in a DataFrame?

# %% [markdown]
# 22. How do you create a new column based on existing columns?

# %% [markdown]
# 23. How do you apply a function to a column?

# %% [markdown]
# 24. How do you group data by a specific column and calculate statistics?

# %% [markdown]
# 25. How do you use .agg() to apply multiple aggregate functions?

# %% [markdown]
# 26. How do you pivot a DataFrame?

# %% [markdown]
# 27. How do you melt (unpivot) a DataFrame?

# %% [markdown]
# 28. How do you merge two DataFrames on a common column?

# %% [markdown]
# 29. How do you join two DataFrames using different types of joins?

# %% [markdown]
# 30. How do you concatenate multiple DataFrames?

# %% [markdown]
# 31. How do you find correlation between numerical columns?

# %% [markdown]
# 32. How do you apply a lambda function to a DataFrame?

# %% [markdown]
# 33. How do you convert a date column to datetime format?

# %% [markdown]
# 34. How do you extract year, month, and day from a datetime column?

# %% [markdown]
# 35. How do you filter rows based on a date range?

# %% [markdown]
# 36. How do you resample a time series DataFrame?

# %% [markdown]
# 37. How do you compute rolling averages on a DataFrame?

# %% [markdown]
# 38. How do you create a crosstab between two columns?

# %% [markdown]
# 39. How do you replace specific values in a column?

# %% [markdown]
# 40. How do you remove duplicate rows from a DataFrame?

# %% [markdown]
# ## Advanced Pandas Questions

# %% [markdown]
# 41. How do you perform a query on a DataFrame?

# %% [markdown]
# 42. How do you create a MultiIndex DataFrame?

# %% [markdown]
# 43. How do you select data from a MultiIndex DataFrame?

# %% [markdown]
# 44. How do you swap levels in a MultiIndex DataFrame?

# %% [markdown]
# 45. How do you reshape a DataFrame using .stack() and .unstack()?

# %% [markdown]
# 46. How do you find the memory usage of a DataFrame?

# %% [markdown]
# 47. How do you optimize the memory usage of a DataFrame?

# %% [markdown]
# 48. How do you create a DataFrame from a dictionary?

# %% [markdown]
# 49. How do you convert a DataFrame into a dictionary?

# %% [markdown]
# 50. How do you convert a DataFrame to a NumPy array?

# %% [markdown]
# 51. How do you convert a DataFrame to an Excel file?

# %% [markdown]
# 52. How do you read an Excel file into a DataFrame?

# %% [markdown]
# 53. How do you work with JSON data in Pandas?

# %% [markdown]
# 54. How do you use .query() for filtering data efficiently?

# %% [markdown]
# 55. How do you perform rank calculations in Pandas?

# %% [markdown]
# 56. How do you find the difference between consecutive rows?

# %% [markdown]
# 57. How do you compute cumulative sum and cumulative product?

# %% [markdown]
# 58. How do you work with categorical data in Pandas?

# %% [markdown]
# 59. How do you map values from one column to another?

# %% [markdown]
# 60. How do you create a DataFrame with hierarchical column indexing?

# %% [markdown]
# ## Pandas Performance Optimization

# %% [markdown]
# 61. How do you use .apply() efficiently instead of loops?

# %% [markdown]
# 62. How do you use .map() for element-wise transformations?

# %% [markdown]
# 63. How do you use .astype() to change data types optimally?

# %% [markdown]
# 64. How do you downcast numerical columns to reduce memory usage?

# %% [markdown]
# 65. How do you use .loc[] vs .iloc[] for better performance?

# %% [markdown]
# 66. How do you use .at[] and .iat[] for accessing single values efficiently?

# %% [markdown]
# 67. How do you speed up DataFrame operations using vectorization?

# %% [markdown]
# 68. How do you use .explode() to split lists into rows?

# %% [markdown]
# 69. How do you parallelize Pandas operations using Dask?

# %% [markdown]
# 70. How do you work with large datasets efficiently using chunk_size?

# %% [markdown]
# ## Visualization with Pandas

# %% [markdown]
# 71. How do you plot a histogram of a column in Pandas?

# %% [markdown]
# 72. How do you plot a line chart from a DataFrame?

# %% [markdown]
# 73. How do you plot a bar chart using Pandas?

# %% [markdown]
# 74. How do you create a scatter plot with Pandas?

# %% [markdown]
# 75. How do you plot a boxplot to visualize distributions?

# %% [markdown]
# 76. How do you customize Pandas plots with Matplotlib?

# %% [markdown]
# 77. How do you use .groupby() with .plot() for comparisons?

# %% [markdown]
# 78. How do you create a heatmap from a DataFrame?

# %% [markdown]
# 79. How do you visualize missing values in a dataset?

# %% [markdown]
# 80. How do you create a pie chart from a Pandas DataFrame?

# %% [markdown]
# ## Real-World Pandas Use Cases (Using Stack Overflow 2019 Data)

# %% [markdown]
# 81. How do you find the most common programming language in the dataset?

# %% [markdown]
# 82. How do you calculate the average salary for each programming language?

# %% [markdown]
# 83. How do you find the top 10 countries by the number of developers?

# %% [markdown]
# 84. How do you analyze the distribution of job satisfaction among developers?

# %% [markdown]
# 85. How do you find which programming languages are most used together?

# %% [markdown]
# 86. How do you analyze trends in developers' years of experience?

# %% [markdown]
# 87. How do you find the most common education level among developers?

# %% [markdown]
# 88. How do you analyze the difference in salary between remote and non-remote workers?

# %% [markdown]
# 89. How do you filter out extreme salary values using quantiles?

# %% [markdown]
# 90. How do you analyze the gender distribution in the dataset?

# %% [markdown]
# 91. How do you check if higher experience leads to higher salary?

# %% [markdown]
# 92. How do you identify outliers in the dataset using Pandas?

# %% [markdown]
# 93. How do you find correlations between salary and other numerical columns?

# %% [markdown]
# 94. How do you create a pivot table to analyze salary trends?

# %% [markdown]
# 95. How do you find the most used IDE in the dataset?

# %% [markdown]
# 96. How do you analyze the impact of open-source contributions on salary?

# %% [markdown]
# 97. How do you find the percentage of developers who work full-time vs part-time?

# %% [markdown]
# 98. How do you analyze trends in developers' preferred technologies over time?

# %% [markdown]
# 99. How do you create a report summarizing key insights from the dataset?

# %% [markdown]
# 100. How do you export the final cleaned dataset as a CSV file?

# %% [markdown]
# # Happy Coding!
#
# We wish you all the best in your coding journey. For solutions to this problem, please click [here](https://github.com/AdarshaRimal/pandas-practical-revision-notes/blob/main/notebooks/100_pandas_questions_solutions.ipynb).
#
# Best regards,
# Adarsha Rimal
